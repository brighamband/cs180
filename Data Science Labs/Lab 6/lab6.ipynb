# %%
import pandas as pd

# %% [markdown]
# #Exercise 1 and 2

# %% [markdown]
# ###Exercise 1 (pt1)

# %%
cfb16 = pd.read_csv('cfb16.csv')
cfb17 = pd.read_csv('cfb17.csv')
cfb18 = pd.read_csv('cfb18.csv')
cfb19 = pd.read_csv('cfb19.csv')
cfb20 = pd.read_csv('cfb20.csv')

# %% [markdown]
# ###Exercise 2

# %%
cfb16["Year"] = 2016
cfb17["Year"] = 2017
cfb18["Year"] = 2018
cfb19["Year"] = 2019
cfb20["Year"] = 2020

# %% [markdown]
# ###Exercise 1 (pt2)

# %%
all_stats = pd.concat([cfb16, cfb17, cfb18, cfb19, cfb20])
all_stats
# Out:
#                            Team  Games  ...  Avg.Turnover.Margin.per.Game  Year
# 0                   Akron (MAC)     12  ...                         -0.67  2016
# 1                 Alabama (SEC)     15  ...                          0.67  2016
# 2    Appalachian St. (Sun Belt)     13  ...                          0.62  2016
# 3              Arizona (Pac-12)     12  ...                         -0.58  2016
# 4          Arizona St. (Pac-12)     12  ...                         -0.33  2016
# ..                          ...    ...  ...                           ...   ...
# 122      West Virginia (Big 12)      9  ...                          0.33  2020
# 123         Western Ky. (C-USA)     11  ...                         -0.27  2020
# 124         Western Mich. (MAC)      6  ...                         -0.50  2020
# 125         Wisconsin (Big Ten)      6  ...                         -0.50  2020
# 126     Wyoming (Mountain West)      6  ...                          0.17  2020
#
# [631 rows x 153 columns]
